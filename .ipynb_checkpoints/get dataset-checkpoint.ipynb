# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install yfinance
# !pip install requests
# !pip install selenium
# !pip install webdriver-manager

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import time
import pickle
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %%
import requests
import sys
import traceback
from getpass import getpass
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# # Get Data

# %% [markdown]
# ## Solana

# %%
solana_df = yf.download("SOL-USD", start="2021-01-01", end=datetime.today().strftime('%Y-%m-%d'))
solana_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2020-12-31   1.535606   1.550610   1.430263   1.510898   1.510898    12763260
# 2021-01-01   1.509775   1.859656   1.502038   1.842084   1.842084    25722549
# 2021-01-02   1.845586   1.989295   1.721482   1.799275   1.799275    31671064
# 2021-01-03   1.799902   2.364981   1.799902   2.161752   2.161752    55073422
# 2021-01-04   2.162412   2.485097   1.876342   2.485097   2.485097    59955405
# ...               ...        ...        ...        ...        ...         ...
# 2022-05-27  43.474380  43.813648  40.268963  40.981346  40.981346  2256358026
# 2022-05-28  41.493732  44.658012  40.548679  44.343163  44.343163  1254325884
# 2022-05-29  44.338791  45.386253  41.998047  44.909615  44.909615  1317843243
# 2022-05-30  44.908669  47.936829  44.357407  47.179443  47.179443  1708817065
# 2022-05-31  47.181328  48.038990  44.840015  45.767841  45.767841  1509191627
#
# [517 rows x 6 columns]

# %%
solana_df.plot(y = "Adj Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Ethereum

# %%
ethereum_df = yf.download("ETH-USD", start="2018-01-01", end=datetime.today().strftime('%Y-%m-%d'))
ethereum_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-12-31   712.211975   760.348022   710.119019   756.732971   756.732971
# 2018-01-01   755.757019   782.530029   742.004028   772.640991   772.640991
# 2018-01-02   772.346008   914.830017   772.346008   884.443970   884.443970
# 2018-01-03   886.000000   974.471008   868.450989   962.719971   962.719971
# 2018-01-04   961.713013  1045.079956   946.085999   980.921997   980.921997
# ...                 ...          ...          ...          ...          ...
# 2022-05-27  1802.543823  1814.656494  1721.264771  1724.922852  1724.922852
# 2022-05-28  1724.635986  1757.941772  1724.635986  1757.941772  1757.941772
# 2022-05-29  1792.184448  1818.776611  1765.937378  1812.031006  1812.031006
# 2022-05-30  1811.885986  2005.210815  1804.456055  1996.441284  1996.441284
# 2022-05-31  1996.408081  2005.490967  1932.352051  1942.328003  1942.328003
#
#                  Volume
# Date
# 2017-12-31   2554269952
# 2018-01-01   2595760128
# 2018-01-02   5783349760
# 2018-01-03   5093159936
# 2018-01-04   6502859776
# ...                 ...
# 2022-05-27  25470760032
# 2022-05-28  23214777872
# 2022-05-29  10642556101
# 2022-05-30  19580808705
# 2022-05-31  18363115560
#
# [1613 rows x 6 columns]

# %%
ethereum_df.plot(y = "Adj Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Bitcoin

# %%
bitcoin_df = yf.download("BTC-USD", start="2018-01-01", end=datetime.today().strftime('%Y-%m-%d'))
bitcoin_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2017-12-31  12897.700195  14377.400391  12755.599609  14156.400391
# 2018-01-01  14112.200195  14112.200195  13154.700195  13657.200195
# 2018-01-02  13625.000000  15444.599609  13163.599609  14982.099609
# 2018-01-03  14978.200195  15572.799805  14844.500000  15201.000000
# 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# ...                  ...           ...           ...           ...
# 2022-05-27  29251.140625  29346.943359  28326.613281  28627.574219
# 2022-05-28  28622.625000  28814.900391  28554.566406  28814.900391
# 2022-05-29  29019.867188  29498.009766  28841.107422  29445.957031
# 2022-05-30  29443.365234  31949.630859  29303.572266  31726.390625
# 2022-05-31  31723.865234  32249.863281  31286.154297  31792.310547
#
#                Adj Close       Volume
# Date
# 2017-12-31  14156.400391  12136299520
# 2018-01-01  13657.200195  10291200000
# 2018-01-02  14982.099609  16846600192
# 2018-01-03  15201.000000  16871900160
# 2018-01-04  15599.200195  21783199744
# ...                  ...          ...
# 2022-05-27  28627.574219  36582005748
# 2022-05-28  28814.900391  35519577634
# 2022-05-29  29445.957031  18093886409
# 2022-05-30  31726.390625  39277993274
# 2022-05-31  31792.310547  33538210634
#
# [1613 rows x 6 columns]

# %%
bitcoin_df.plot(y = "Adj Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin_df = bitcoin_df.reset_index()[['Date', 'Adj Close', 'Volume']]
bitcoin_df.rename(columns={"Date": "dates", "Adj Close" : "btc adj close", "Volume" : "btc volume"}, inplace = True)
bitcoin_df['dates'] = bitcoin_df['dates'].astype(str)

ethereum_df = ethereum_df.reset_index()[['Date', 'Adj Close', 'Volume']]
ethereum_df.rename(columns={"Date": "dates", "Adj Close" : "eth adj close", "Volume" : "eth volume"}, inplace = True)
ethereum_df['dates'] = ethereum_df['dates'].astype(str)

solana_df = solana_df.reset_index()[['Date', 'Adj Close', 'Volume']]
solana_df.rename(columns={"Date": "dates", "Adj Close" : "sol adj close", "Volume" : "sol volume"}, inplace = True)
solana_df['dates'] = solana_df['dates'].astype(str)

# %% [markdown]
# ## Rarible

# %%
dict_collections = {}
list_broken_urls = []
url_top_100 = 'https://api-mainnet.rarible.com/marketplace/api/v4/collections/top?days=30&size=100'
url_collections = 'https://rarible-cdn.reallm.io/collections/{}/{}?filters=%7B%7D'
broken_collection_url = 'https://rarible.com/collection/{}/stats?range=-Number.MAX_SAFE_INTEGER'
list_features = ['marketcap', 'lowwatermark', 'transactions', 'owners', 'sellers', 'buyers']


def get_collections_id(url):
    json = requests.get(
        url
    ).json()

    df_id = pd.DataFrame.from_dict(json)
    df_id = df_id[['id', 'name']]
    return df_id


def change_collection_data(df, feature):
    if feature == 'prices':
        df.rename(columns = {'dates': 'dates'}, inplace = True)
    elif feature == 'marketcap':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'marketcap'}, inplace = True)
        df = df[['dates', 'marketcap']]
    elif feature == 'lowwatermark':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'lowwatermark'}, inplace = True)
        df = df[['dates', 'lowwatermark']]
    elif feature == 'transactions':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'amount_transactions'}, inplace = True)
        df = df[['dates', 'amount_transactions']]
    elif feature == 'owners':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'amount_owners'}, inplace = True)
        df = df[['dates', 'amount_owners']]
    elif feature == 'sellers':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'amount_sellers'}, inplace = True)
        df = df[['dates', 'amount_sellers']]
    elif feature == 'buyers':
        df.rename(columns = {'graph_dates': 'dates',
                            'graph_values': 'amount_buyers'}, inplace = True)
        df = df[['dates', 'amount_buyers']]
    
    return df


def get_collection_data(id, features):
    df = pd.read_json(url_collections.format(id, 'prices'))
    for feature in features:
        tmp = pd.read_json(url_collections.format(id, feature))
        df = df.merge(change_collection_data(tmp, feature), how='left', on='dates')
        
    return df


def add_stocks(df):
    df = df.merge(bitcoin_df, how='left', on='dates')
    df = df.merge(ethereum_df, how='left', on='dates')
    df = df.merge(solana_df, how='left', on='dates')
    
    return df


def replace_nan(df):
    for i in df.columns[df.isnull().any(axis=0)]:
        for index, value in df[i].items():
            if np.isnan(value):
                try:
                    df[i].at[index] = df[i].iloc[index-3: index].mean()
                except:
                    pass

    return df    


def work_with_stocks(df):
    df['change in btc'] = df['btc adj close'] - df['btc adj close'].shift()
    df['change in eth'] = df['eth adj close'] - df['eth adj close'].shift()
    df['change in sol'] = df['sol adj close'] - df['sol adj close'].shift()
    
    return df


df_id = get_collections_id(url_top_100)
for index, row in df_id.iterrows():
    try:
        tmp = get_collection_data(row['id'], list_features)
        tmp = replace_nan(tmp)
        tmp = add_stocks(tmp)
        tmp = work_with_stocks(tmp)
        dict_collections[row['name']] = tmp
        print("collection:", row['name'], "done")
    except:
        print("collection:", row['name'], "has not got dataset")
        print("url:", broken_collection_url.format(row['id']))
        list_broken_urls.append(broken_collection_url.format(row['id']))
        pass
# Out:
# collection: Otherdeed done
# collection: Azuki done
# collection: projectPXN done
# collection: Bored Ape Yacht Club done
# collection: MutantApeYachtClub done
# collection: BEANZ Official done
# collection: goblintown done
# collection: CloneX done
# collection: Doodles done
# collection: Moonbirds done
# collection: Murakami.Flowers done
# collection: Art Blocks Factory done
# collection: Murakami.Flowers Seed done
# collection: ENS domains has not got dataset
# url: https://rarible.com/collection/0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85/stats?range=-Number.MAX_SAFE_INTEGER
# collection: Chimpers done
# collection: Ragnarok done
# collection: DEGEN TOONZ done
# collection: Genesis done
# collection: Mindblowon done
# collection: Meebits done
# collection: AIMoonbirds done
# collection: Bored Ape Chemistry Club done
# collection: BoredApeKennelClub done
# collection: adidas Originals: Into the Metaverse done
# collection: Rektguy done
# collection: VeeFriends Series 2 done
# collection: RTFKT - MNLTH done
# collection: Boki done
# collection: Moonbirds Oddities done
# collection: Cool Cats done
# collection: Something Token done
# collection: RTFKT X NIKE MONOLITH done
# collection: Imaginary Ones done
# collection: TBAC done
# collection: 10KTF done
# collection: CPG Pop done
# collection: Dooplicator done
# collection: Milady Maker has not got dataset
# url: https://rarible.com/collection/0x5af0d9827e0c53e4799bb226655a1de152a425a5/stats?range=-Number.MAX_SAFE_INTEGER
# collection: Karafuru Gachapon done
# collection: BBRC OFFICIAL - IVY BOYS done
# collection: World Of Women done
# collection: Art Blocks Curated has not got dataset
# url: https://rarible.com/collection/0x059edd72cd353df5106d2b9cc5ab83a52287ac3a/stats?range=-Number.MAX_SAFE_INTEGER
# collection: Karafuru done
# collection: Blvck Genesis done
# collection: PREMINT Collector Pass - OFFICIAL done
# collection: Admit One done
# collection: Invisible Friends done
# collection: Sandbox's LANDs done
# collection: Project NANOPASS done
# collection: NFT Worlds done
# collection: PROOF Collective done
# collection: Elftown.wtf done
# collection: 3Landers done
# collection: Lofi Originals done
# collection: The Art of Seasons done
# collection: CyberBrokers done
# collection: Town Star has not got dataset
# url: https://rarible.com/collection/0xc36cf0cfcb5d905b8b513860db0cfe63f6cf9f5c/stats?range=-Number.MAX_SAFE_INTEGER
# collection: mfer done
# collection: Regulars done
# collection: VeeFriends done
# collection: Cyber Factory 2 done
# collection: Akutars done
# collection: GOBLIN GRLZ done
# collection: Tigerbob done
# collection: Quirkies Originals done
# collection: 10KTF Stockroom done
# collection: Kahiru done
# collection: OkayBearsYachtClub done
# collection: Nouns done
# collection: Oddstronauts done
# collection: World Of Women Galaxy done
# collection: Akumu Dragonz done
# collection: MNLTHRVLD done
# collection: Psychedelics Anonymous Genesis done
# collection: Impostors Genesis Aliens done
# collection: KaijuKingz done
# collection: IDZ done
# collection: Cheers UP Period done
# collection: Trait Sniper done
# collection: Rareland done
# collection: Kith Friends done
# collection: MURI done
# collection: pieceofshit done
# collection: Pixelated Llama done
# collection: KILLABEARS done
# collection: ForgottenRunesWizardsCult done
# collection: Fragments By James Jean done
# collection: FLUF done
# collection: Cool Pets done
# collection: DeadFellaz done
# collection: PLUR done
# collection: CyberKongz has not got dataset
# url: https://rarible.com/collection/0x57a204aa1042f6e66dd7730813f4024114d74f37/stats?range=-Number.MAX_SAFE_INTEGER
# collection: Cryptoadz done
# collection: Pixelmon - Generation 1 done
# collection: RTFKT SKIN VIAL: EVO X done
# collection: Flippr Access Pass done
# collection: MOAR by Joan Cornella done
# collection: TheCurrency done
# collection: Project Godjira Generation 2 done
# collection: NFT Worlds - Genesis Avatars Whitelist Passes done

# %%
with open('dataset.pkl', 'wb') as f:
    pickle.dump(dict_collections, f)

# %%
dict_collections['MutantApeYachtClub']
# Out:
#           dates    prices_avg  prices_floor  prices_median        volume  \
# 0    2021-08-29  30573.945494      0.000000   25978.451172  1.706332e+08
# 1    2021-08-30  42150.432895      0.000000   32023.800781  4.611257e+07
# 2    2021-08-31  34728.502238      0.000000   28324.003906  1.972579e+07
# 3    2021-09-01  34049.167712   1848.198730   24513.210938  1.637765e+07
# 4    2021-09-02  26299.774417  12414.097656   22857.037109  1.041471e+07
# ..          ...           ...           ...            ...           ...
# 267  2022-05-28  31780.733774  28392.847656   31653.021484  4.131495e+05
# 268  2022-05-29  31283.230239  27646.226562   30659.912109  5.318149e+05
# 269  2022-05-30  36870.326782  31727.736328   34265.976562  5.899252e+05
# 270  2022-05-31  36696.986979  33767.875000   35332.902344  2.201819e+05
# 271  2022-06-01  38490.454688  35734.117188   37087.648438  1.924523e+05
#
#         marketcap  lowwatermark  amount_transactions  amount_owners  \
# 0    9.277673e+03     21245.703                 5581         7080.0
# 1    3.916317e+06     20522.010                 1094         7503.0
# 2    7.019255e+06     20522.010                  568         7693.0
# 3    2.655862e+07     20522.010                  481         7793.0
# 4    1.794458e+08     20522.010                  396         7933.0
# ..            ...           ...                  ...            ...
# 267  5.261195e+08     24113.527                   13        13935.0
# 268  5.122846e+08     24113.527                   17        13943.0
# 269  5.879150e+08     24113.527                   16        13964.0
# 270  6.257187e+08     24113.527                    6        13977.0
# 271  6.621532e+08     24113.527                    5        13989.0
#
#      amount_sellers  amount_buyers  btc adj close    btc volume  \
# 0               5.0      37.000000   48829.832031  2.588965e+10
# 1               2.0      46.000000   47054.984375  3.184701e+10
# 2               3.0      24.000000   47166.687500  3.473036e+10
# 3               6.0      42.000000   48847.027344  3.913940e+10
# 4               9.0      21.000000   49327.722656  3.950807e+10
# ..              ...            ...            ...           ...
# 267           190.0       1.011433   28814.900391  3.551958e+10
# 268           149.0       1.008922   29445.957031  1.809389e+10
# 269            80.0       1.011896   31726.390625  3.927799e+10
# 270            48.0       1.010750   31792.310547  3.353821e+10
# 271            35.0       1.010522            NaN           NaN
#
#      eth adj close    eth volume  sol adj close    sol volume  change in btc  \
# 0      3227.002686  1.329659e+10      94.469673  1.830344e+09            NaN
# 1      3224.374268  1.930692e+10     110.544807  5.274104e+09   -1774.847656
# 2      3433.732666  2.728050e+10     108.483772  7.590894e+09     111.703125
# 3      3834.828125  3.007089e+10     111.033005  3.974444e+09    1680.339844
# 4      3790.989990  2.438740e+10     128.102386  5.074400e+09     480.695312
# ..             ...           ...            ...           ...            ...
# 267    1757.941772  2.321478e+10      44.343163  1.254326e+09     187.326172
# 268    1812.031006  1.064256e+10      44.909615  1.317843e+09     631.056641
# 269    1996.441284  1.958081e+10      47.179443  1.708817e+09    2280.433594
# 270    1942.328003  1.836312e+10      45.767841  1.509192e+09      65.919922
# 271            NaN           NaN            NaN           NaN            NaN
#
#      change in eth  change in sol
# 0              NaN            NaN
# 1        -2.628418      16.075134
# 2       209.358398      -2.061035
# 3       401.095459       2.549232
# 4       -43.838135      17.069382
# ..             ...            ...
# 267      33.018921       3.361816
# 268      54.089233       0.566452
# 269     184.410278       2.269829
# 270     -54.113281      -1.411602
# 271            NaN            NaN
#
# [272 rows x 20 columns]
